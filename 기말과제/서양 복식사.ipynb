# %%
from GoogleNgrams import Ngrams
import pandas as pd, matplotlib.pyplot as plt

# %%
rev = Ngrams('Revolution', language = 'eng_gb_2019')
rev.plot()
# Out:
# <AxesSubplot:>

# %%
a =Ngrams('tail coat')
a.plot()
# Out:
# <AxesSubplot:>

# %% [markdown]
# a1 =Ngrams('sack coat',start=1800, end=1900)
# #색 코트는 나폴레옹 3세 시기 등장, 일상적인 복장으로 1860년부터 스포츠 웨어로
# #frock coat
# a1.plot()

# %%
b = Ngrams('shawl')
b.plot()
# Out:
# <AxesSubplot:>

# %% [markdown]
# c = Ngrams('breeches', start=1800, end= 1900)
# #귀족의 상징인 무릎 길이 바지
# #-> 프랑스 혁명을 계기로 사라지고 서민들과 같이 발목길이 바지 착용
# c.plot()

# %% [markdown]
# c1 = Ngrams('pantaloons', start=1800, end= 1900)
# #프랑스 혁명 이후 서민복에서 귀족들이 채택한 복식
# c1.plot()

# %%
d = Ngrams('chemise', start=1800, end= 1900, language='fre_2019')
#d = Ngrams('chemise', language='fre_2019')
d.plot()
#이건 사용 못할 것 같은데ㅠㅠ
# Out:
# <AxesSubplot:>

# %%
d1 = Ngrams('crinoline', start=1800, end=1900, language='fre_2019')
#왕정 복고 시기에 철사로 만든 둥근 모양의 속옷으로 화려한 상징
d1.plot()
# Out:
# <AxesSubplot:>

# %%
d2 = Ngrams('agitation', start=1800, end=1900, language='fre_2019')
d2.plot()
# Out:
# <AxesSubplot:>

# %%
d3 = Ngrams('tailored suit', start=1800, end=1900)
d3.plot()
#???
# Out:
# <AxesSubplot:>

# %%
e = Ngrams('corset', start=1800, end=1870, language='fre_2019')
e.plot()
#???
# Out:
# <AxesSubplot:>

# %% [markdown]
# f = Ngrams('Liberté',start=1800, end=1870, language = 'fre_2019')
# #Egalité
# #프랑스 혁명 정신 : 자유, 평등, 연대
# f.plot()

# %% [markdown]
# f1 = Ngrams('Egalité',start=1800, end=1870, language = 'fre_2019')
# #프랑스 혁명 정신 : 자유, 평등, 연대
# f1.plot()

# %% [markdown]
# g = Ngrams('Bloomer',start=1800, end=1900)
# #19세기말 블루머주의(Bloomerism): 남녀평등 사회운동
# #-> 체조, 승마, 사이클링 즐기는 여성 증가
# g.plot()
